# %%
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib.gridspec import GridSpec


from matplotlib import rc

# %%
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

# %%
def format_axes(fig):
    for i, ax in enumerate(fig.axes):
        ax.tick_params(labelbottom=True, labelleft=True)
        
def PlotRow(FileName, XLabel, YLabel, title, axis):
    FrictionData = pd.read_csv(FileName,sep=";",header=None,names=["time", "Tau", "Slip"])
    FrictionData.plot(x=XLabel[0], y=YLabel[0], title = title, ax=axis)
    axis.set_xlabel(XLabel[1])
    axis.set_ylabel(YLabel[1])
    
def PlotRows(FileName,ListOfAxes,title):
    PlotRow(FileName, ["time","$Time$"], ["Tau","$Tau$"], title, ListOfAxes[0])
    PlotRow(FileName, ["time","$Time$"], ["Slip","$Slip$"], title, ListOfAxes[1])

# %%
ListFilenames=["../Output/Drama.txt"]
Titles = ["Rate and State"]




fig = plt.figure(constrained_layout=True, figsize=(20,10))

gs = GridSpec(1, 3, figure=fig)
for j in range(1):
    ax1 = [fig.add_subplot(gs[j, i]) for i in range(2)]
    PlotRows(ListFilenames[j],ax1,Titles[j])



fig.suptitle("Friction Laws")
format_axes(fig)

plt.show()

# %%
FrictionData = pd.read_csv(ListFilenames[0],sep=";",header=None,names=["time", "Tau", "Slip"])

# %%
FrictionData
# Out:
#       time       Tau      Slip
# 0    0.001  0.000000  0.003000
# 1    0.002  0.000001  0.006000
# 2    0.003  0.000001  0.009001
# 3    0.004  0.000002  0.012001
# 4    0.005  0.000002  0.015002
# 5    0.006  0.000003  0.018003
# 6    0.007  0.000003  0.021004
# 7    0.008  0.000004  0.024005
# 8    0.009  0.000004  0.027006
# 9    0.010  0.000005  0.030007
# 10   0.011  0.000005  0.033008
# 11   0.012  0.000006  0.036010
# 12   0.013  0.000006  0.039011
# 13   0.014  0.000007  0.042013
# 14   0.015  0.000007  0.045015
# 15   0.016  0.000008  0.048017
# 16   0.017  0.000008  0.051019
# 17   0.018  0.000009  0.054021
# 18   0.019  0.000009  0.057024
# 19   0.020  0.000010  0.060026
# 20   0.021  0.000010  0.063029
# 21   0.022  0.000011  0.066032
# 22   0.023  0.000011  0.069034
# 23   0.024  0.000012  0.072037
# 24   0.025  0.000012  0.075040
# 25   0.026  0.000012  0.078044
# 26   0.027  0.000013  0.081047
# 27   0.028  0.000013  0.084050
# 28   0.029  0.000014  0.087054
# 29   0.030  0.000014  0.090058
# ..     ...       ...       ...
# 969  0.970  0.000466  2.965538
# 970  0.971  0.000466  2.968653
# 971  0.972  0.000467  2.971768
# 972  0.973  0.000467  2.974882
# 973  0.974  0.000468  2.977997
# 974  0.975  0.000468  2.981112
# 975  0.976  0.000468  2.984227
# 976  0.977  0.000469  2.987342
# 977  0.978  0.000469  2.990458
# 978  0.979  0.000470  2.993573
# 979  0.980  0.000470  2.996689
# 980  0.981  0.000471  2.999804
# 981  0.982  0.000471  3.002920
# 982  0.983  0.000472  3.006036
# 983  0.984  0.000472  3.009152
# 984  0.985  0.000473  3.012268
# 985  0.986  0.000473  3.015385
# 986  0.987  0.000474  3.018501
# 987  0.988  0.000474  3.021617
# 988  0.989  0.000475  3.024734
# 989  0.990  0.000475  3.027851
# 990  0.991  0.000476  3.030968
# 991  0.992  0.000476  3.034085
# 992  0.993  0.000477  3.037202
# 993  0.994  0.000477  3.040319
# 994  0.995  0.000478  3.043436
# 995  0.996  0.000478  3.046554
# 996  0.997  0.000479  3.049671
# 997  0.998  0.000479  3.052789
# 998  0.999  0.000480  3.055907
#
# [999 rows x 3 columns]
