# %%
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib.gridspec import GridSpec


from matplotlib import rc

# %%
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

# %%
def format_axes(fig):
    for i, ax in enumerate(fig.axes):
        ax.tick_params(labelbottom=True, labelleft=True)
        
def PlotRow(FileName, XLabel, YLabel, title, axis):
    FrictionData = pd.read_csv(FileName,sep=";",header=None,names=["time", "Tau", "Slip"])
    FrictionData.plot(x=XLabel[0], y=YLabel[0], title = title, ax=axis)
    axis.set_xlabel(XLabel[1])
    axis.set_ylabel(YLabel[1])
    
def PlotRows(FileName,ListOfAxes,title):
    PlotRow(FileName, ["time","$Time$"], ["Tau","$Tau$"], title, ListOfAxes[0])
    PlotRow(FileName, ["time","$Time$"], ["Slip","$Slip$"], title, ListOfAxes[1])

# %%
ListFilenames=["../Output/Drama.txt"]
Titles = ["Rate and State"]




fig = plt.figure(constrained_layout=True, figsize=(20,10))

gs = GridSpec(1, 3, figure=fig)
for j in range(1):
    ax1 = [fig.add_subplot(gs[j, i]) for i in range(2)]
    PlotRows(ListFilenames[j],ax1,Titles[j])



fig.suptitle("Friction Laws")
format_axes(fig)

plt.show()

# %%
FrictionData = pd.read_csv(ListFilenames[0],sep=";",header=None,names=["time", "Tau", "Slip"])

# %%
FrictionData
# Out:
#       time        Tau       Slip
# 0    0.001  70.203295   0.000000
# 1    0.002  70.203295   3.455910
# 2    0.003  70.203295   1.475164
# 3    0.004  70.203295   0.330359
# 4    0.005  70.203295   0.000000
# 5    0.006  70.203295   0.000000
# 6    0.007  70.203295   0.000000
# 7    0.008  70.203295   0.000000
# 8    0.009  70.203295   0.000000
# 9    0.010  70.203295   0.000000
# 10   0.011  70.203295   0.000000
# 11   0.012  70.203295   0.000000
# 12   0.013  70.203295   0.000000
# 13   0.014  70.203295   0.000000
# 14   0.015  70.203295   0.000000
# 15   0.016  70.203295   0.000000
# 16   0.017  70.203295   0.000000
# 17   0.018  70.203295   0.000000
# 18   0.019  70.203295   0.000000
# 19   0.020  70.203295   0.000000
# 20   0.021  70.203295   0.000000
# 21   0.022  70.203295   0.000000
# 22   0.023  70.203295   0.000000
# 23   0.024  70.203295   0.000000
# 24   0.025  70.203295   0.000000
# 25   0.026  70.203295   0.000000
# 26   0.027  70.203295   0.000000
# 27   0.028  70.203295   0.000000
# 28   0.029  70.203295   0.000000
# 29   0.030  70.203295   0.000000
# ..     ...        ...        ...
# 969  0.970  70.203295  42.121977
# 970  0.971  70.203295  42.121977
# 971  0.972  70.203295  42.121977
# 972  0.973  70.203295  42.121977
# 973  0.974  70.203295  42.121977
# 974  0.975  70.203295  42.121977
# 975  0.976  70.203295  42.121977
# 976  0.977  70.203295  42.121977
# 977  0.978  70.203295  42.121977
# 978  0.979  70.203295  42.121977
# 979  0.980  70.203295  42.121977
# 980  0.981  70.203295  42.121977
# 981  0.982  70.203295  42.121977
# 982  0.983  70.203295  42.121977
# 983  0.984  70.203295  42.121977
# 984  0.985  70.203295  42.121977
# 985  0.986  70.203295  42.121977
# 986  0.987  70.203295  42.121977
# 987  0.988  70.203295  42.121977
# 988  0.989  70.203295  42.121977
# 989  0.990  70.203295  42.121977
# 990  0.991  70.203295  42.121977
# 991  0.992  70.203295  42.121977
# 992  0.993  70.203295  42.121977
# 993  0.994  70.203295  42.121977
# 994  0.995  70.203295  42.121977
# 995  0.996  70.203295  42.121977
# 996  0.997  70.203295  42.121977
# 997  0.998  70.203295  42.121977
# 998  0.999  70.203295  42.121977
#
# [999 rows x 3 columns]
