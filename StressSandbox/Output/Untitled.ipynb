# %%
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib.gridspec import GridSpec


from matplotlib import rc

# %%
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

# %%
def format_axes(fig):
    for i, ax in enumerate(fig.axes):
        ax.tick_params(labelbottom=True, labelleft=True)
        
def PlotRow(FileName, XLabel, YLabel, title, axis):
    FrictionData = pd.read_csv(FileName,sep=";",header=None,names=["time", "Tau", "Slip"])
    FrictionData.plot(x=XLabel[0], y=YLabel[0], title = title, ax=axis)
    axis.set_xlabel(XLabel[1])
    axis.set_ylabel(YLabel[1])
    
def PlotRows(FileName,ListOfAxes,title):
    PlotRow(FileName, ["time","$Time$"], ["Tau","$Tau$"], title, ListOfAxes[0])
    PlotRow(FileName, ["time","$Time$"], ["Slip","$Slip$"], title, ListOfAxes[1])

# %%
ListFilenames=["../Output/Drama.txt"]
Titles = ["Rate and State"]




fig = plt.figure(constrained_layout=True, figsize=(20,10))

gs = GridSpec(1, 3, figure=fig)
for j in range(1):
    ax1 = [fig.add_subplot(gs[j, i]) for i in range(2)]
    PlotRows(ListFilenames[j],ax1,Titles[j])



fig.suptitle("Friction Laws")
format_axes(fig)

plt.show()
# Out:
# /home/nico/miniconda3/envs/jane/lib/python3.5/site-packages/matplotlib/font_manager.py:1238: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/nico/miniconda3/envs/jane/lib/python3.5/site-packages/matplotlib/font_manager.py:1238: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
FrictionData = pd.read_csv(ListFilenames[0],sep=";",header=None,names=["time", "Tau", "Slip"])

# %%
FrictionData
# Out:
#       time       Tau   Slip
# 0    0.001 -0.000001  0.003
# 1    0.002 -0.000002  0.006
# 2    0.003 -0.000003  0.009
# 3    0.004 -0.000004  0.012
# 4    0.005 -0.000005  0.015
# 5    0.006 -0.000006  0.018
# 6    0.007 -0.000007  0.021
# 7    0.008 -0.000008  0.024
# 8    0.009 -0.000009  0.027
# 9    0.010 -0.000010  0.030
# 10   0.011 -0.000011  0.033
# 11   0.012 -0.000012  0.036
# 12   0.013 -0.000012  0.039
# 13   0.014 -0.000013  0.042
# 14   0.015 -0.000014  0.045
# 15   0.016 -0.000015  0.048
# 16   0.017 -0.000016  0.051
# 17   0.018 -0.000017  0.054
# 18   0.019 -0.000018  0.057
# 19   0.020 -0.000019  0.060
# 20   0.021 -0.000020  0.063
# 21   0.022 -0.000021  0.066
# 22   0.023 -0.000022  0.069
# 23   0.024 -0.000023  0.072
# 24   0.025 -0.000024  0.075
# 25   0.026 -0.000025  0.078
# 26   0.027 -0.000026  0.081
# 27   0.028 -0.000027  0.084
# 28   0.029 -0.000028  0.087
# 29   0.030 -0.000029  0.090
# ..     ...       ...    ...
# 969  0.970 -0.000931  2.910
# 970  0.971 -0.000932  2.913
# 971  0.972 -0.000933  2.916
# 972  0.973 -0.000934  2.919
# 973  0.974 -0.000935  2.922
# 974  0.975 -0.000936  2.925
# 975  0.976 -0.000937  2.928
# 976  0.977 -0.000938  2.931
# 977  0.978 -0.000939  2.934
# 978  0.979 -0.000940  2.937
# 979  0.980 -0.000941  2.940
# 980  0.981 -0.000942  2.943
# 981  0.982 -0.000943  2.946
# 982  0.983 -0.000944  2.949
# 983  0.984 -0.000945  2.952
# 984  0.985 -0.000946  2.955
# 985  0.986 -0.000947  2.958
# 986  0.987 -0.000948  2.961
# 987  0.988 -0.000948  2.964
# 988  0.989 -0.000949  2.967
# 989  0.990 -0.000950  2.970
# 990  0.991 -0.000951  2.973
# 991  0.992 -0.000952  2.976
# 992  0.993 -0.000953  2.979
# 993  0.994 -0.000954  2.982
# 994  0.995 -0.000955  2.985
# 995  0.996 -0.000956  2.988
# 996  0.997 -0.000957  2.991
# 997  0.998 -0.000958  2.994
# 998  0.999 -0.000959  2.997
#
# [999 rows x 3 columns]
