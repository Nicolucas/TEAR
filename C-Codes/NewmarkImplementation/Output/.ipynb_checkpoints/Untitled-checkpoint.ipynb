# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib.gridspec import GridSpec
from matplotlib import rc

# %%
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

# %%
def format_axes(fig):
    for i, ax in enumerate(fig.axes):
        ax.tick_params(labelbottom=True, labelleft=True)
    
        
def PlotRow(FileName, XLabel, YLabel, title, axis):
    FrictionData = pd.read_csv(FileName,sep=";",header=None,names=["time", "Slip", "SlipDot","Theta", "Friction","Traction"])
    FrictionData.plot(x=XLabel[0], y=YLabel[0], title = title, ax=axis)
    axis.set_xlabel(XLabel[1])
    axis.set_ylabel(YLabel[1])
    axis.get_legend().remove()
    
def PlotRows(FileName,ListOfAxes,title):
    PlotRow(FileName, ["time","$time$"], ["Slip","$Slip$"], title, ListOfAxes[0])
    PlotRow(FileName, ["time","$time$"], ["Traction","$Traction$"], title, ListOfAxes[1])
    PlotRow(FileName, ["time","$time$"], ["Friction","$Friction$"], title, ListOfAxes[2])
    PlotRow(FileName, ["Slip","$Slip$"], ["Friction","$Friction$"], title, ListOfAxes[3])

# %%
ListFilenames=["../Output/Demo_01.txt", "../Output/Demo_02.txt", "../Output/Demo_03.txt"]
Titles = ["","",""]


fig = plt.figure(constrained_layout=True, figsize=(9,5))

gs = GridSpec(4, 4, figure=fig)
for j in range(3):
    ax1 = [fig.add_subplot(gs[j, i]) for i in range(4)]
    PlotRows(ListFilenames[j],ax1,Titles[j])




fig.suptitle("Friction Laws: Linear Slip Weakening")
format_axes(fig)

plt.savefig("../Output/Linear.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
# /home/nico/miniconda3/envs/jane/lib/python3.5/site-packages/matplotlib/font_manager.py:1238: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/nico/miniconda3/envs/jane/lib/python3.5/site-packages/matplotlib/font_manager.py:1238: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
FrictionData = pd.read_csv(ListFilenames[0],sep=";",header=None,index_col=None,names=["time", "Slip", "SlipDot","Theta", "Friction","Traction"])

# %%
FrictionData
# Out:
#          time      Slip  SlipDot  Theta  Friction  Traction
# 0      0.0001  0.000001      0.0    1.0  0.600000   0.00002
# 1      0.0002  0.000001      0.0    1.0  0.600000   0.00002
# 2      0.0003  0.000001      0.0    1.0  0.600000   0.00002
# 3      0.0004  0.000001      0.0    1.0  0.600000   0.00002
# 4      0.0005  0.000001      0.0    1.0  0.600000   0.00002
# 5      0.0006  0.000001      0.0    1.0  0.600000   0.00002
# 6      0.0007  0.000001      0.0    1.0  0.600000   0.00002
# 7      0.0008  0.000001      0.0    1.0  0.600000   0.00002
# 8      0.0009  0.000001      0.0    1.0  0.600000   0.00002
# 9      0.0010  0.000001      0.0    1.0  0.600000   0.00002
# 10     0.0011  0.000001      0.0    1.0  0.600000   0.00002
# 11     0.0012  0.000001      0.0    1.0  0.600000   0.00002
# 12     0.0013  0.000001      0.0    1.0  0.600000   0.00002
# 13     0.0014  0.000001      0.0    1.0  0.600000   0.00002
# 14     0.0015  0.000001      0.0    1.0  0.600000   0.00002
# 15     0.0016  0.000001      0.0    1.0  0.600000   0.00002
# 16     0.0017  0.000001      0.0    1.0  0.600000   0.00002
# 17     0.0018  0.000001      0.0    1.0  0.600000   0.00002
# 18     0.0019  0.000001      0.0    1.0  0.600000   0.00002
# 19     0.0020  0.000001      0.0    1.0  0.600000   0.00002
# 20     0.0021  0.000001      0.0    1.0  0.600000   0.00002
# 21     0.0022  0.000001      0.0    1.0  0.600000   0.00002
# 22     0.0023  0.000001      0.0    1.0  0.600000   0.00002
# 23     0.0024  0.000001      0.0    1.0  0.600000   0.00002
# 24     0.0025  0.000001      0.0    1.0  0.600000   0.00002
# 25     0.0026  0.000001      0.0    1.0  0.600000   0.00002
# 26     0.0027  0.000001      0.0    1.0  0.600000   0.00002
# 27     0.0028  0.000001      0.0    1.0  0.600000   0.00002
# 28     0.0029  0.000001      0.0    1.0  0.600000   0.00002
# 29     0.0030  0.000001      0.0    1.0  0.600000   0.00002
# ...       ...       ...      ...    ...       ...       ...
# 99969  9.9970  0.000003      0.0    1.0  0.599999   0.00004
# 99970  9.9971  0.000003      0.0    1.0  0.599999   0.00004
# 99971  9.9972  0.000003      0.0    1.0  0.599999   0.00004
# 99972  9.9973  0.000003      0.0    1.0  0.599999   0.00004
# 99973  9.9974  0.000003      0.0    1.0  0.599999   0.00004
# 99974  9.9975  0.000003      0.0    1.0  0.599999   0.00004
# 99975  9.9976  0.000003      0.0    1.0  0.599999   0.00004
# 99976  9.9977  0.000003      0.0    1.0  0.599999   0.00004
# 99977  9.9978  0.000003      0.0    1.0  0.599999   0.00004
# 99978  9.9979  0.000003      0.0    1.0  0.599999   0.00004
# 99979  9.9980  0.000003      0.0    1.0  0.599999   0.00004
# 99980  9.9981  0.000003      0.0    1.0  0.599999   0.00004
# 99981  9.9982  0.000003      0.0    1.0  0.599999   0.00004
# 99982  9.9983  0.000003      0.0    1.0  0.599999   0.00004
# 99983  9.9984  0.000003      0.0    1.0  0.599999   0.00004
# 99984  9.9985  0.000003      0.0    1.0  0.599999   0.00004
# 99985  9.9986  0.000003      0.0    1.0  0.599999   0.00004
# 99986  9.9987  0.000003      0.0    1.0  0.599999   0.00004
# 99987  9.9988  0.000003      0.0    1.0  0.599999   0.00004
# 99988  9.9989  0.000003      0.0    1.0  0.599999   0.00004
# 99989  9.9990  0.000003      0.0    1.0  0.599999   0.00004
# 99990  9.9991  0.000003      0.0    1.0  0.599999   0.00004
# 99991  9.9992  0.000003      0.0    1.0  0.599999   0.00004
# 99992  9.9993  0.000003      0.0    1.0  0.599999   0.00004
# 99993  9.9994  0.000003      0.0    1.0  0.599999   0.00004
# 99994  9.9995  0.000003      0.0    1.0  0.599999   0.00004
# 99995  9.9996  0.000003      0.0    1.0  0.599999   0.00004
# 99996  9.9997  0.000003      0.0    1.0  0.599999   0.00004
# 99997  9.9998  0.000003      0.0    1.0  0.599999   0.00004
# 99998  9.9999  0.000003      0.0    1.0  0.599999   0.00004
#
# [99999 rows x 6 columns]
