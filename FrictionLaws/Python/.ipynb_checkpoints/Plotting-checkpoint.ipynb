# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
FrictionData = pd.read_csv("../Output/TestSW.txt",sep=";",header=None,names=["Tau", "Slip"])
FrictionData.plot(x="Slip", y="Tau", title = "Slip Weakening")
FrictionData = pd.read_csv("../Output/TestSR.txt",sep=";",header=None,names=["Tau", "Slip"])
FrictionData.plot(x="Slip", y="Tau", title = "Rate and State friction")
FrictionData = pd.read_csv("../Output/TestModSR.txt",sep=";",header=None,names=["Tau", "Slip"])
FrictionData.plot(x="Slip", y="Tau",title = "Modified Rate and State friction")
