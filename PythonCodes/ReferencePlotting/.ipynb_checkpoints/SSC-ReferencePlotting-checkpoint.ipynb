# %%
from glob import glob
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('seaborn-whitegrid')
from matplotlib import cm
import numpy as np
import math
from scipy import signal


cmap = cm.get_cmap("plasma_r")

# %%
def Butterworth_Low(Signal,CutoffFrequency = 10 ,SamplingFrequency = 200):
    NormFrequency = CutoffFrequency / (SamplingFrequency / 2.0)
    
    b,a = signal.butter(1, NormFrequency, "low")
    output =  signal.filtfilt(b, a, np.asarray(Signal)).tolist()
    return output


def CalculateKostrovSolution(Time,Stress,mu, v,r):
    result = (24/(7*np.pi))*(Stress/mu)*np.sqrt((v**2)*(Time**2)-r**2)
    if math.isnan(result):
        return 0.0
    else:
        return result

# %%
def PlotBimatReference(ax, SlipSlipRate):
    FileNameDict = {"Slip" : "slip (m)", "SlipRate" : "slip rate (m/s)", "Shear":"shear stress (Pa)"}
    for NumStat in range(1,5):
        Station = pd.read_csv("/home/nico/Tools/bimat_1.1.2/BIMAT-PCSI/EXAMPLES/SelfSimilarCrack/pcsi_SSC.obs{}".format(NumStat), delimiter=r"\s+",header=None,
                             names=["time (s)" , "slip rate (m/s)", "slip (m)", "shear stress (Pa)", "normal stress (Pa)","strength (Pa)"])
        
        ax.plot(Station["time (s)"],Butterworth_Low(Station[FileNameDict[SlipSlipRate]]), ls= ":")
    ax.set_xlabel("time (s)")
    ax.set_ylabel(FileNameDict[SlipSlipRate])


def PlotSem2dpackReference(ax, path, SlipSlipRate):
    FileNameDict = {"Slip" : "slip", "SlipRate" : "sr", "Shear":"sxy"}
    ListReference = sorted(glob(path+"sem2dpack/sem2d-{}-*.txt".format(FileNameDict[SlipSlipRate])))
    
    
    
    for idx, item in enumerate(ListReference):
        line = pd.read_csv(item,header=None)
        
        if SlipSlipRate=="Shear":
            line[1] = line[1]*10e5
        ax.plot(line[0],Butterworth_Low(line[1]),c = cmap(idx/6), label = "", ls = "--")
        
    ax.set_xlabel("time (s)")
    FileNameDict = {"Slip" : "slip (m)", "SlipRate" : "slip rate (m/s)", "Shear":"shear stress (Pa)"}
    ax.set_ylabel(FileNameDict[SlipSlipRate])

# %%
path="/home/nico/Documents/TEAR/Codes_TEAR/ProfilePicking/Output/Reference/"

fig = plt.figure(figsize = (14,12))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
        

ax1.set_xlim([0,4])
ax1.set_ylim([-2,9])
ax2.set_xlim([0,4])
ax2.set_ylim([-2,10])
ax3.set_xlim([0,4])
    
    
fig.suptitle('BIMAT (dot.) \nvs sem2dpack (dashed)', fontsize=21)

PlotBimatReference(ax1, "Slip")
PlotBimatReference(ax2, "SlipRate")
PlotBimatReference(ax3, "Shear")


PlotSem2dpackReference(ax1,path,"Slip")
PlotSem2dpackReference(ax2,path,"SlipRate")
PlotSem2dpackReference(ax3,path,"Shear")

# %%
fig = plt.figure(figsize = (14,10))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.set_xlim([0,4])
ax2.set_xlim([0,4])


Stress = 10.0e6 
ElasticShearModulus = 13.333e9
Velocity = 2.0e3
TimeList = np.arange(0, 5, 0.01).tolist()

for r in [0,2000,4000,6000,8000]:
    Slip = [CalculateKostrovSolution(Time,Stress,ElasticShearModulus, Velocity,r) for Time in TimeList]
    ax1.plot(TimeList,Slip)
    SlipRate = np.gradient(Slip, TimeList[1]-TimeList[0],edge_order=2) 
    
    ax2.plot(TimeList,SlipRate)

fig.suptitle('Bimat vs sem2dpack vs \nKostrov self-similar circular crack', fontsize=21)
PlotBimatReference(ax1, "Slip"); PlotBimatReference(ax2, "SlipRate")
PlotSem2dpackReference(ax1,path,"Slip"); PlotSem2dpackReference(ax2,path,"SlipRate")
# Out:
# /home/nico/miniconda3/envs/jane/lib/python3.5/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Out:
# (0, (1, 1))
