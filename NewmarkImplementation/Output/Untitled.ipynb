# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib.gridspec import GridSpec
from matplotlib import rc

# %%
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

# %%
def format_axes(fig):
    for i, ax in enumerate(fig.axes):
        ax.tick_params(labelbottom=True, labelleft=True)
        
def PlotRow(FileName, XLabel, YLabel, title, axis):
    FrictionData = pd.read_csv(FileName,sep=";",header=None,names=["time", "Slip", "SlipDot","Theta", "Friction","Traction"])
    FrictionData.plot(x=XLabel[0], y=YLabel[0], title = title, ax=axis)
    axis.set_xlabel(XLabel[1])
    axis.set_ylabel(YLabel[1])
    
def PlotRows(FileName,ListOfAxes,title):
    PlotRow(FileName, ["time","$time$"], ["Slip","$Slip$"], title, ListOfAxes[0])
    PlotRow(FileName, ["time","$time$"], ["Traction","$Traction$"], title, ListOfAxes[1])
    PlotRow(FileName, ["time","$time$"], ["Friction","$Friction$"], title, ListOfAxes[2])
    PlotRow(FileName, ["Slip","$Slip$"], ["Friction","$Friction$"], title, ListOfAxes[3])

# %%
ListFilenames=["../Output/Demo_01.txt","../Output/Demo_02.txt","../Output/Demo_03.txt"]
Titles = ["","",""]




fig = plt.figure(constrained_layout=True, figsize=(9,5))

gs = GridSpec(4, 4, figure=fig)
for j in range(3):
    ax1 = [fig.add_subplot(gs[j, i]) for i in range(4)]
    PlotRows(ListFilenames[j],ax1,Titles[j])



fig.suptitle("Friction Laws: Rate and State")
format_axes(fig)

plt.savefig("../Output/Linear.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
FrictionData = pd.read_csv(ListFilenames[0],sep=";",header=None,index_col=None,names=["time", "Slip", "SlipDot","Theta", "Friction","Traction"])

# %%
FrictionData
# Out:
#       time      Slip  SlipDot  Theta  Friction  Traction
# 0    0.001  0.100204      0.0    1.0  0.048569  0.120243
# 1    0.002  0.100206      0.0    1.0  0.048568  0.120244
# 2    0.003  0.100208      0.0    1.0  0.048568  0.120245
# 3    0.004  0.100210      0.0    1.0  0.048568  0.120246
# 4    0.005  0.100212      0.0    1.0  0.048568  0.120247
# 5    0.006  0.100214      0.0    1.0  0.048568  0.120249
# 6    0.007  0.100216      0.0    1.0  0.048568  0.120250
# 7    0.008  0.100218      0.0    1.0  0.048568  0.120251
# 8    0.009  0.100220      0.0    1.0  0.048568  0.120252
# 9    0.010  0.100222      0.0    1.0  0.048568  0.120253
# 10   0.011  0.100224      0.0    1.0  0.048568  0.120255
# 11   0.012  0.100226      0.0    1.0  0.048568  0.120256
# 12   0.013  0.100228      0.0    1.0  0.048568  0.120257
# 13   0.014  0.100230      0.0    1.0  0.048568  0.120258
# 14   0.015  0.100232      0.0    1.0  0.048568  0.120259
# 15   0.016  0.100234      0.0    1.0  0.048568  0.120261
# 16   0.017  0.100236      0.0    1.0  0.048568  0.120262
# 17   0.018  0.100238      0.0    1.0  0.048568  0.120263
# 18   0.019  0.100240      0.0    1.0  0.048568  0.120264
# 19   0.020  0.100242      0.0    1.0  0.048568  0.120265
# 20   0.021  0.100244      0.0    1.0  0.048568  0.120267
# 21   0.022  0.100246      0.0    1.0  0.048568  0.120268
# 22   0.023  0.100248      0.0    1.0  0.048568  0.120269
# 23   0.024  0.100250      0.0    1.0  0.048568  0.120270
# 24   0.025  0.100252      0.0    1.0  0.048568  0.120271
# 25   0.026  0.100254      0.0    1.0  0.048568  0.120273
# 26   0.027  0.100256      0.0    1.0  0.048568  0.120274
# 27   0.028  0.100258      0.0    1.0  0.048568  0.120275
# 28   0.029  0.100260      0.0    1.0  0.048568  0.120276
# 29   0.030  0.100262      0.0    1.0  0.048568  0.120277
# ..     ...       ...      ...    ...       ...       ...
# 969  0.970  0.102144      0.0    1.0  0.048541  0.121407
# 970  0.971  0.102146      0.0    1.0  0.048541  0.121408
# 971  0.972  0.102148      0.0    1.0  0.048541  0.121409
# 972  0.973  0.102150      0.0    1.0  0.048541  0.121410
# 973  0.974  0.102152      0.0    1.0  0.048541  0.121411
# 974  0.975  0.102154      0.0    1.0  0.048541  0.121413
# 975  0.976  0.102156      0.0    1.0  0.048541  0.121414
# 976  0.977  0.102158      0.0    1.0  0.048541  0.121415
# 977  0.978  0.102160      0.0    1.0  0.048541  0.121416
# 978  0.979  0.102162      0.0    1.0  0.048541  0.121417
# 979  0.980  0.102164      0.0    1.0  0.048541  0.121419
# 980  0.981  0.102166      0.0    1.0  0.048540  0.121420
# 981  0.982  0.102168      0.0    1.0  0.048540  0.121421
# 982  0.983  0.102170      0.0    1.0  0.048540  0.121422
# 983  0.984  0.102172      0.0    1.0  0.048540  0.121423
# 984  0.985  0.102174      0.0    1.0  0.048540  0.121425
# 985  0.986  0.102176      0.0    1.0  0.048540  0.121426
# 986  0.987  0.102178      0.0    1.0  0.048540  0.121427
# 987  0.988  0.102180      0.0    1.0  0.048540  0.121428
# 988  0.989  0.102182      0.0    1.0  0.048540  0.121429
# 989  0.990  0.102184      0.0    1.0  0.048540  0.121431
# 990  0.991  0.102186      0.0    1.0  0.048540  0.121432
# 991  0.992  0.102188      0.0    1.0  0.048540  0.121433
# 992  0.993  0.102190      0.0    1.0  0.048540  0.121434
# 993  0.994  0.102192      0.0    1.0  0.048540  0.121435
# 994  0.995  0.102194      0.0    1.0  0.048540  0.121437
# 995  0.996  0.102196      0.0    1.0  0.048540  0.121438
# 996  0.997  0.102198      0.0    1.0  0.048540  0.121439
# 997  0.998  0.102200      0.0    1.0  0.048540  0.121440
# 998  0.999  0.102202      0.0    1.0  0.048540  0.121441
#
# [999 rows x 6 columns]
